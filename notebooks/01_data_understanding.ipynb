# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.append(os.path.abspath(".."))


from src.preprocessing.loaders import load_air_data 
from src.preprocessing.duplicates import (
    check_duplicate,
    get_duplicate,
    get_duplicate_temporel_partiel,
    remove_duplicates
)

df = load_air_data("../data/raw/AirQualityUCI.csv")

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   str
#  1   Time           9357 non-null   str
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(15), str(2)
# ...

# %%
df.dtypes
# Out:
# Date                 str
# Time                 str
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
# supression de deux colonnes vides de notre dataFrame 


df.drop(columns= ["Unnamed: 15", "Unnamed: 16"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 4
#       1 # supression de deux colonnes vides de notre dataFrame
#       2
#       3
# ----> 4 df.drop(columns= ["Unnamed: 15", "Unnamed: 16"], inplace=True)
#
# File c:\air-quality-ai-platform\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\air-quality-ai-platform\.venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# suprimer les lignes totalements vides 

df.dropna(how="all", inplace=True)

# %%
# verifiction de la taille du dataset 

df.shape
# Out:
# (9357, 15)

# %% [markdown]
# # doublons
# ## Duplicate detecion

# %%
duplic = check_duplicate(data = df)
print(f" Number of duplicates rows : {duplic}")
# Out:
#  Number of duplicates rows : 0

# %%
df[get_duplicate(data=df)]
# Out:
#      Date Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 1     NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 2     NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 3     NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 4     NaN  NaN     NaN          NaN       NaN       NaN            NaN
# ...   ...  ...     ...          ...       ...       ...            ...
# 9352  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9353  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9354  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9355  NaN  NaN     NaN          NaN       NaN       NaN            NaN
# 9356  NaN  NaN     NaN          NaN       NaN       NaN            NaN
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH  AH
# ...

# %% [markdown]
# # supression des doublons complets

# %%
df = remove_duplicates(data=df)

# %%
duplic = check_duplicate(data = df)
print(f" Number of duplicates rows : {duplic}")
# Out:
#  Number of duplicates rows : 0

# %% [markdown]
# # doublons partiels

# %%
get_duplicate_temporel_partiel(data=df).sum()
# Out:
# np.int64(0)

# %%
df['Date'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['Time'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.groupby(["Date", "Time"])

# %%
df.groupby(["Date", "Time"]).size().sort_values(ascending=False)
# Out:
# Date        Time
# 01/01/2005  00.00.00    1
#             01.00.00    1
#             02.00.00    1
#             03.00.00    1
#             04.00.00    1
#                        ..
# 31/12/2004  19.00.00    1
#             20.00.00    1
#             21.00.00    1
#             22.00.00    1
#             23.00.00    1
# Length: 9357, dtype: int64

# %%
df.groupby(["Date", "Time"]).size().sort_values(ascending=False)
# Out:
# Date        Time
# 01/01/2005  00.00.00    1
#             01.00.00    1
#             02.00.00    1
#             03.00.00    1
#             04.00.00    1
#                        ..
# 31/12/2004  19.00.00    1
#             20.00.00    1
#             21.00.00    1
#             22.00.00    1
#             23.00.00    1
# Length: 9357, dtype: int64

# %%
# il ya aucune doublons partiel donc cest unile de faire les operations sur les doubblans partiels

# %%
df.replace(-200,np.nan, inplace=True)
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...
